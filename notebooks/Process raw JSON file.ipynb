# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 41298692-226c-4607-ab23-de1b66ab35d3)

# %%
df = df.select('value')
display(df)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4dfb812b-951b-4d5a-a4a3-3ced49d40c55)

# %%
from pyspark.sql.functions import explode

df_exploded = df.select(explode(df['value']).alias('json_object'))

display(df_exploded)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 16, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7d56bad8-c31f-49ae-907e-207b7d70e27a)

# %%
json_list = df_exploded.toJSON().collect()

print(json_list)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 17, Finished, Available, Finished)
# ['{"json_object":{"about":[{"name":"Rosjanie","readLink":"https://api.bing.microsoft.com/api/v7/entities/bf145061-36ee-21a4-f79d-fb29ef1b77ff"},{"name":"Sumy","readLink":"https://api.bing.microsoft.com/api/v7/entities/7a5eb2e6-e493-088b-8af4-4dd09dc10bec"}],"datePublished":"2024-09-17T00:13:00.0000000Z","description":"Rosjanie rozpoczęli zmasowany atak z “Shahedami” na Sumy (atak ilustracyjny w sprawie miasta Sumy. O tej sprawie poinformowała służba prasowa OVA Sumy. „Wyjaśniane są skutki ataku, wszystkie służby pracują nad usunięciem skutków ataku” – głosi komunikat.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.EpbfqwQFf2mHfay2Vpozdi&pid=News","height":375,"width":600}},"name":"Rosjanie rozpoczęli zmasowany atak „Shahedami” na Sumy","provider":[{"_type":"Organization","name":"geopolityka.org"}],"url":"https://geopolityka.org/20240917/rosjanie-rozpoczeli-zmasowany-atak-shahedami-na-sumy/"}}', '{"json_object":{"datePublished":"2024-09-16T03:42:00.0000000Z","description":"Scenariusze przygotowane przez hydrologów i obowiązujące jeszcze wczoraj, okazały się niedoszacowane - przekazał prezydent Wrocławia Jacek Sutryk. W związku z tym, że do miasta ma przypłynąć jeszcze w","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.thVLfgODBvYZ4hmkBw7VFC&pid=News","height":393,"width":700}},"name":"Alarm przeciwpowodziowy we Wrocławiu. Gotowi na \\"najczarniejszy scenariusz\\"","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.gqghbhQ0lymmjp4YAd1iQw&pid=news"}},"name":"polsatnews"}],"url":"https://www.polsatnews.pl/wiadomosc/2024-09-16/wroclaw-przygotowuje-sie-na-najgorsze-ogloszono-alarm-przeciwpowodziowy/"}}', '{"json_object":{"about":[{"name":"West Palm Beach","readLink":"https://api.bing.microsoft.com/api/v7/entities/aead1964-17b2-46fb-a0ed-3c8a8d014a7e"},{"name":"Donald Trump","readLink":"https://api.bing.microsoft.com/api/v7/entities/1a466af2-ed23-25bd-794d-1ca925e4681b"},{"name":"Butler","readLink":"https://api.bing.microsoft.com/api/v7/entities/bd2854ec-8a81-ece8-7d9f-19846ecd0a9c"}],"datePublished":"2024-09-15T21:44:00.0000000Z","description":"W Trump National Golf Club w West Palm Beach, gdzie Donald Trump grał w golfa, doszło do strzelaniny. A stało się to niemal dokładnie dwa miesiące po tym, gdy zamachowiec strzelił do polityka na","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.2CycIxm_YdAK2I66O8mQ-i&pid=News","height":367,"width":700}},"name":"Kolejna próba zamachu na Donalda Trumpa? Na polu golfowym polityka doszło do strzelaniny","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.S98F8jIiuGzSo7XWBjLcxA&pid=news"}},"name":"Fakt.pl"}],"url":"https://www.fakt.pl/polityka/kolejna-proba-zamachu-na-donalda-trumpa/v6gvgsf"}}', '{"json_object":{"datePublished":"2024-09-12T19:33:00.0000000Z","description":"Pliki cookie, identyfikatory urządzeń lub podobne identyfikatory online (np. identyfikatory oparte na logowaniu, identyfikatory przypisywane losowo, identyfikatory sieciowe) w połączeniu z innymi info","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.ogKxMA6cOVUXZP1y4qgOyy&pid=News","height":522,"width":700}},"name":"Operacja Sobowtór. Amerykańscy influencerzy na liście Kremla","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.tgiy-cRQKhwtVXtXiqgsCA&pid=news"}},"name":"GAZETA PRAWNA"}],"url":"https://www.gazetaprawna.pl/magazyn-na-weekend/artykuly/9603522,operacja-sobowtor-amerykanscy-influencerzy-na-liscie-kremla.html"}}', '{"json_object":{"about":[{"name":"Long COVID","readLink":"https://api.bing.microsoft.com/api/v7/entities/0c9f5ae6-9561-aa80-8fbd-78f6ef843ac7"},{"name":"University College London","readLink":"https://api.bing.microsoft.com/api/v7/entities/20b640eb-2f1a-2b91-14f3-348b9a1bf371"}],"datePublished":"2024-09-04T07:59:00.0000000Z","description":"Pain is the most common and serious sy ...

# %%
print(json_list[0])
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 27, Finished, Available, Finished)
# {"json_object":{"about":[{"name":"Rosjanie","readLink":"https://api.bing.microsoft.com/api/v7/entities/bf145061-36ee-21a4-f79d-fb29ef1b77ff"},{"name":"Sumy","readLink":"https://api.bing.microsoft.com/api/v7/entities/7a5eb2e6-e493-088b-8af4-4dd09dc10bec"}],"datePublished":"2024-09-17T00:13:00.0000000Z","description":"Rosjanie rozpoczęli zmasowany atak z “Shahedami” na Sumy (atak ilustracyjny w sprawie miasta Sumy. O tej sprawie poinformowała służba prasowa OVA Sumy. „Wyjaśniane są skutki ataku, wszystkie służby pracują nad usunięciem skutków ataku” – głosi komunikat.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.EpbfqwQFf2mHfay2Vpozdi&pid=News","height":375,"width":600}},"name":"Rosjanie rozpoczęli zmasowany atak „Shahedami” na Sumy","provider":[{"_type":"Organization","name":"geopolityka.org"}],"url":"https://geopolityka.org/20240917/rosjanie-rozpoczeli-zmasowany-atak-shahedami-na-sumy/"}}

# %%
import json

title = []
description = []
image = []
url = []
provider = []
datePublished = []

for article in json_list:
    try:
        article = json.loads(article)
        if article['json_object'].get('image'):
            title.append(article['json_object']['name'])
            description.append(article['json_object']['description'])
            image.append(article['json_object']['image']['thumbnail']['contentUrl'])
            url.append(article['json_object']['url'])
            provider.append(article['json_object']['provider'])
            datePublished.append(article['json_object']['datePublished'])
    except Exception as e:
        print(f"Error occurred: {e}")
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 18, Finished, Available, Finished)

# %%
from pyspark.sql.types import StringType, StructField, StructType

data = list(zip(title, description, image, url, provider, datePublished))

schema = StructType([
    StructField("title", StringType(), True),
    StructField("description", StringType(), True),
    StructField("image", StringType(), True),
    StructField("url", StringType(), True),
    StructField("provider", StringType(), True),
    StructField("datePublished", StringType(), True),
])

df_cleaned = spark.createDataFrame(data, schema=schema)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 19, Finished, Available, Finished)

# %%
display(df_cleaned)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 20, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1857476d-e474-4f7e-953a-dbb687f3239f)

# %%
from pyspark.sql.functions import to_date, date_format

df_cleaned_final = df_cleaned.withColumn('datePublished', date_format(to_date(df_cleaned.datePublished), 'dd-MMM-yyyy'))
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 21, Finished, Available, Finished)

# %%
from pyspark.sql.utils import AnalysisException

try:
    table = 'bing_lake_database.latest_news' #TODO

    df_cleaned_final.write.format("delta").saveAsTable(table)

except AnalysisException:
    print('Table already exists.')

    df_cleaned_final.createOrReplaceTempView('temp_latest_news')

    spark.sql(f"""  MERGE INTO {table} target_table
                    USING temp_latest_news source_view

                    ON source_view.url = target_table.url

                    WHEN MATCHED AND
                    source_view.title <> target_table.title OR
                    source_view.description <> target_table.description OR
                    source_view.image <> target_table.image OR
                    source_view.url <> target_table.url OR
                    source_view.provider <> target_table.provider OR
                    source_view.datePublished <> target_table.datePublished

                    THEN UPDATE SET *

                    WHEN NOT MATCHED THEN INSERT *

                """)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 25, Finished, Available, Finished)
# Table already exists.

# %%
df = spark.sql("SELECT * FROM bing_lake_database.latest_news LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 6d33f561-1a65-4558-aeab-a8d586964bfd, 26, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 816eb652-b810-4057-a712-cc25bd807ec4)

# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
